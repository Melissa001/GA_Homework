# %% [markdown]
# # Project 2
#
# In this project, you will implement the exploratory analysis plan developed in Project 1. This will lay the groundwork for our our first modeling exercise in Project 3.

# %% [markdown]
# ### Step 1: Load the python libraries you will need for this project

# %%
#imports
from __future__ import division
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
import pylab as pl
import numpy as np
# %matplotlib inline

# %% [markdown]
# ### Step 2: Read in your data set

# %%
#Read in data from source 
df_raw = pd.read_csv("../assets/admissions.csv")
print df_raw.head()
# Out:
#    admit    gre   gpa  prestige
# 0      0  380.0  3.61       3.0
# 1      1  660.0  3.67       3.0
# 2      1  800.0  4.00       1.0
# 3      1  640.0  3.19       4.0
# 4      0  520.0  2.93       4.0

# %% [markdown]
# ## Questions
# #### Question 1. How many observations are in our dataset?

# %%
df_raw.count()
# Out:
# admit       400
# gre         398
# gpa         398
# prestige    399
# dtype: int64

# %% [markdown]
# Answer:

# %% [markdown]
# #### Question 2. Create a summary table

# %%
df_raw.describe()
# Out:
# C:\Users\melissa\AppData\Local\Continuum\Anaconda2\lib\site-packages\numpy\lib\function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#             admit         gre        gpa    prestige
# count  400.000000  398.000000  398.00000  399.000000
# mean     0.317500  588.040201    3.39093    2.486216
# std      0.466087  115.628513    0.38063    0.945333
# min      0.000000  220.000000    2.26000    1.000000
# 25%      0.000000         NaN        NaN         NaN
# 50%      0.000000         NaN        NaN         NaN
# 75%      1.000000         NaN        NaN         NaN
# max      1.000000  800.000000    4.00000    4.000000

# %% [markdown]
# #### Question 3. Why would GRE have a larger STD than GPA?

# %% [markdown]
# Answer: There is higher variability in the data

# %% [markdown]
# #### Question 4. Drop data points with missing data

# %%
df_raw.isnull()
# Out:
#      admit    gre    gpa prestige
# 0    False  False  False    False
# 1    False  False  False    False
# 2    False  False  False    False
# 3    False  False  False    False
# 4    False  False  False    False
# 5    False  False  False    False
# 6    False  False  False    False
# 7    False  False  False    False
# 8    False  False  False    False
# 9    False  False  False    False
# 10   False  False  False    False
# 11   False  False  False    False
# 12   False  False  False    False
# 13   False  False  False    False
# 14   False  False  False    False
# 15   False  False  False    False
# 16   False  False  False    False
# 17   False  False  False    False
# 18   False  False  False    False
# 19   False  False  False    False
# 20   False  False  False    False
# 21   False  False  False    False
# 22   False  False  False    False
# 23   False  False  False    False
# 24   False  False  False    False
# 25   False  False  False    False
# ...

# %%
df_raw.dropna()
# Out:
#      admit    gre   gpa  prestige
# 0        0  380.0  3.61       3.0
# 1        1  660.0  3.67       3.0
# 2        1  800.0  4.00       1.0
# 3        1  640.0  3.19       4.0
# 4        0  520.0  2.93       4.0
# 5        1  760.0  3.00       2.0
# 6        1  560.0  2.98       1.0
# 7        0  400.0  3.08       2.0
# 8        1  540.0  3.39       3.0
# 9        0  700.0  3.92       2.0
# 10       0  800.0  4.00       4.0
# 11       0  440.0  3.22       1.0
# 12       1  760.0  4.00       1.0
# 13       0  700.0  3.08       2.0
# 14       1  700.0  4.00       1.0
# 15       0  480.0  3.44       3.0
# 16       0  780.0  3.87       4.0
# 17       0  360.0  2.56       3.0
# 18       0  800.0  3.75       2.0
# 19       1  540.0  3.81       1.0
# 20       0  500.0  3.17       3.0
# 21       1  660.0  3.63       2.0
# 22       0  600.0  2.82       4.0
# 23       0  680.0  3.19       4.0
# 24       1  760.0  3.35       2.0
# 25       1  800.0  3.66       1.0
# ...

# %% [markdown]
# #### Question 5. Confirm that you dropped the correct data. How can you tell?

# %% [markdown]
# Answer: We should have less values after dropping the values

# %% [markdown]
# #### Question 6. Create box plots for GRE and GPA

# %%
df_raw['gre'].plot(kind='box')

# %%
df_raw['gpa'].plot(kind='box')

# %% [markdown]
# #### Question 7. What do this plots show?

# %% [markdown]
# Answer: variability in the dataset, outliers

# %% [markdown]
# #### Question 8. Describe each distribution

# %%
df_raw.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000000C142780>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000BDD4320>]], dtype=object)

# %% [markdown]
# #### Question 9.  If our model had an assumption of a normal distribution would we meet that requirement?

# %% [markdown]
# Answer: The distribution for gre and gpa look skewed

# %% [markdown]
# #### Question 10.  Does this distribution need correction? If so, why? How?

# %% [markdown]
# Answer:

# %% [markdown]
# #### Question 11. Which of our variables are potentially colinear?

# %%
df_raw.corr()
# Out:
#              admit       gre       gpa  prestige
# admit     1.000000  0.182919  0.175952 -0.241355
# gre       0.182919  1.000000  0.382408 -0.124533
# gpa       0.175952  0.382408  1.000000 -0.059031
# prestige -0.241355 -0.124533 -0.059031  1.000000

# %% [markdown]
# #### Question 12. What did you find?

# %% [markdown]
# Answer: There is a correlation between gre and gpa with 0.38

# %% [markdown]
# #### Question 13. Write an analysis plan for exploring the association between grad school admissions rates and prestige of  undergraduate schools.

# %% [markdown]
# Answer: Apply regression modelling to determine if there is any statistical significance between the grad school admission and prestige undergrad schools

# %% [markdown]
# #### Question 14. What is your hypothesis?

# %% [markdown]
# Answer: The admission rates are not affected by prestige undergraduate schools

# %% [markdown]
# ## Bonus/Advanced

# %% [markdown]
# #### 1. Bonus: Explore alternatives to dropping obervations with missing data

# %% [markdown]
# #### 2. Bonus: Log transform the skewed data

# %% [markdown]
# #### 3. Advanced: Impute missing data
